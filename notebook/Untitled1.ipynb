# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
from functools import reduce

path_mammalia = "../data/animalia_chordata/mammalia/"
on_column = "internalTaxonId"

def import_files_from_directory_into_list(directory_path):
    files_list = [f for f in listdir(directory_path) if isfile(join(directory_path, f))]
    df_list = []
    for i in files_list:
        df = pd.read_csv(directory_path + i)
        df_list.append(df)
    return df_list

def merge_df_list (on_column,df_list):
    df = reduce(lambda x, y: pd.merge(x, y, on = on_column), df_list)
    return df

# %%
df_list = import_files_from_directory_into_list(path_mammalia)
mammalia = merge_df_list(on_column,df_list)
mammalia
# Out:
#       assessmentId  internalTaxonId      scientificName_x  redlistCategory  \
# 0           503146            11481         Lemmus lemmus    Least Concern
# 1           503908            11797    Lepus castroviejoi       Vulnerable
# 2           510082            12835       Marmota marmota    Least Concern
# 3           513175            13462      Microtus felteni    Least Concern
# 4           513559            13486      Microtus thomasi    Least Concern
# ...            ...              ...                   ...              ...
# 5963     209552009           136765       Nyctalus furvus       Endangered
# 5964     209552552           136823  Eptesicus japonensis       Vulnerable
# 5965     209553422         71529901    Setirostris eleryi  Near Threatened
# 5966     209553784            13564    Miniopterus fuscus       Endangered
# 5967     209554228         71534469       Ozimops petersi    Least Concern
#
#      redlistCriteria  yearPublished           assessmentDate  criteriaVersion  \
# 0                NaN           2016  2016-08-11 00:00:00 UTC              3.1
# 1            B1ab(v)           2019  2018-06-01 00:00:00 UTC              3.1
# 2                NaN           2016  2016-02-18 00:00:00 UTC              3.1
# 3                NaN           2019  2018-06-19 00:00:00 UTC              3.1
# 4                NaN           2016  2016-09-03 00:00:00 UTC              3.1
# ...              ...            ...                      ...              ...
# 5963    B2ab(ii,iii)           2020  2018-07-05 00:00:00 UTC              3.1
# 5964       B2ab(iii)           2020  2018-07-25 00:00:00 UTC              3.1
# 5965          C2a(i)           2021  2016-07-31 00:00:00 UTC              3.1
# 5966       B2ab(iii)           2021  2018-07-25 00:00:00 UTC              3.1
# 5967             NaN           2021  2018-08-31 00:00:00 UTC              3.1
#
#      language                                          rationale  ...  \
# 0     English  A common and widespread species with no major ...  ...
# 1     English  The Broom Hare is restricted to a relatively s...  ...
# 2     English  Global and European regional assessment: Least...  ...
# 3     English  The species is endemic to Europe and restricte...  ...
# 4     English  A common species within its range, with no maj...  ...
# ...       ...                                                ...  ...
# 5963  English  <span id="docs-internal-guid-862f873d-7fff-b19...  ...
# 5964  English  <span id="docs-internal-guid-8de00154-7fff-4ef...  ...
# 5965  English  <p><span lang="EN-AU">This assessment is based...  ...
# 5966  English  This species is assessed as Endangered under c...  ...
# 5967  English  This species has a large extent of occurrence ...  ...
#
#        orderName        familyName    genusName   speciesName infraType  \
# 0       RODENTIA        CRICETIDAE       Lemmus        lemmus       NaN
# 1     LAGOMORPHA         LEPORIDAE        Lepus  castroviejoi       NaN
# 2       RODENTIA         SCIURIDAE      Marmota       marmota       NaN
# 3       RODENTIA        CRICETIDAE     Microtus       felteni       NaN
# 4       RODENTIA        CRICETIDAE     Microtus       thomasi       NaN
# ...          ...               ...          ...           ...       ...
# 5963  CHIROPTERA  VESPERTILIONIDAE     Nyctalus        furvus       NaN
# 5964  CHIROPTERA  VESPERTILIONIDAE    Eptesicus    japonensis       NaN
# 5965  CHIROPTERA        MOLOSSIDAE  Setirostris        eleryi       NaN
# 5966  CHIROPTERA     MINIOPTERIDAE  Miniopterus        fuscus       NaN
# 5967  CHIROPTERA        MOLOSSIDAE      Ozimops       petersi       NaN
#
#      infraName infraAuthority subpopulationName  \
# 0          NaN            NaN               NaN
# 1          NaN            NaN               NaN
# 2          NaN            NaN               NaN
# 3          NaN            NaN               NaN
# 4          NaN            NaN               NaN
# ...        ...            ...               ...
# 5963       NaN            NaN               NaN
# 5964       NaN            NaN               NaN
# 5965       NaN            NaN               NaN
# 5966       NaN            NaN               NaN
# 5967       NaN            NaN               NaN
#
#                            authority  \
# 0                   (Linnaeus, 1758)
# 1                     Palacios, 1977
# 2                   (Linnaeus, 1758)
# 3           Malec &amp; Storch, 1963
# 4           (Barrett-Hamilton, 1903)
# ...                              ...
# 5963  Imaizumi &amp; Yoshiyuki, 1968
# 5964                  Imaizumi, 1953
# 5965  (Reardon &amp; McKenzie, 2008)
# 5966                   Bonhote, 1902
# 5967                   (Leche, 1884)
#
#                                          taxonomicNotes
# 0             Will be transferred to family Cricetidae.
# 1     <span class="datalabel1"><em>Lepus castroviejo...
# 2                                                   NaN
# 3     Formerly considered a subspecies of <i>Microtu...
# 4     Sometimes considered as a subspecies of <i>M. ...
# ...                                                 ...
# 5963                                                NaN
# 5964                                                NaN
# 5965  <span lang="EN-AU">The generic status of <em>S...
# 5966                                                NaN
# 5967  <em>Ozimops petersi</em> was resurrected recen...
#
# [5968 rows x 37 columns]

# %%
df_habitats = []
for i in habitats_files_list:
    df = pd.read_csv('../data/habitats/' + i)
    df["habitats"] = i
    df["habitats"] = df["habitats"].str[:-4]
    df_habitats.append(df)

# %%
habitats = pd.concat(df_habitats)
habitats
# Out:
#        assessmentId  internalTaxonId        scientificName  \
# 0            495907            10041   Heosemys annandalii
# 1            505402            12124      Lissemys scutata
# 2            511745            13039  Melanochelys trijuga
# 3            544192            13873      Morenia ocellata
# 4            544248            13874       Morenia petersi
# ...             ...              ...                   ...
# 19243     209535016         71531227     Ozimops lumsdenae
# 19244     209550467         71533043         Ozimops ridei
# 19245     209553784            13564    Miniopterus fuscus
# 19246     209554228         71534469       Ozimops petersi
# 19247     210023750           166137     Carassius cuvieri
#
#              redlistCategory   redlistCriteria  yearPublished  \
# 0      Critically Endangered          A2cd+4cd           2021
# 1              Least Concern               NaN           2021
# 2              Least Concern               NaN           2020
# 3                 Endangered          A2cd+4cd           2021
# 4                 Endangered          A2cd+4cd           2021
# ...                      ...               ...            ...
# 19243          Least Concern               NaN           2021
# 19244          Least Concern               NaN           2017
# 19245             Endangered         B2ab(iii)           2021
# 19246          Least Concern               NaN           2021
# 19247             Endangered  A2c; B1ab(iii,v)           2019
#
#                 assessmentDate  criteriaVersion language  \
# 0      2018-03-13 00:00:00 UTC              3.1  English
# 1      2018-03-14 00:00:00 UTC              3.1  English
# 2      2018-03-12 00:00:00 UTC              3.1  English
# 3      2018-03-05 00:00:00 UTC              3.1  English
# 4      2018-03-13 00:00:00 UTC              3.1  English
# ...                        ...              ...      ...
# 19243  2016-07-31 00:00:00 UTC              3.1  English
# 19244  2016-07-29 00:00:00 UTC              3.1  English
# 19245  2018-07-25 00:00:00 UTC              3.1  English
# 19246  2018-08-31 00:00:00 UTC              3.1  English
# 19247  2017-12-08 00:00:00 UTC              3.1  English
#
#                                                rationale  ...  \
# 0      <p><em>Heosemys annandalii</em> is considered ...  ...
# 1      <em>Lissemys scutata</em> is listed as Least C...  ...
# 2      <p>A widespread, adaptable species with a subs...  ...
# 3      <p><em>Morenia ocellata</em> is listed as Enda...  ...
# 4      <p><em>Morenia petersi</em> appears to have su...  ...
# ...                                                  ...  ...
# 19243  <p><span class="datalabel1"><em>Ozimops lumsde...  ...
# 19244  <p><span lang="EN-AU">This species has a large...  ...
# 19245  This species is assessed as Endangered under c...  ...
# 19246  This species has a large extent of occurrence ...  ...
# 19247  This species has undergone at least a 50% popu...  ...
#
#                                                    range  \
# 0      <p>The range of <em>Heosemys annandalii</em> i...
# 1      <em>Lissemys scutata</em> is endemic to Myanma...
# 2      <p><em>Melanochelys trijuga</em> occurs across...
# 3      <p><em>Morenia ocellata</em> was generally con...
# 4      <p><em>Morenia petersi</em> occurs widely thro...
# ...                                                  ...
# 19243  <p><span lang="EN-US">This bat species occurs ...
# 19244  <p><span lang="EN-US">This species occurs alon...
# 19245  <p><span lang="EN-US">This species is endemic ...
# 19246  A widespread species found in arid to semi-ari...
# 19247  <span>This species is endemic to Lake Biwa and...
#
#                                                 useTrade  \
# 0      The species is collected for local consumption...
# 1      <em>Lissemys scutata</em> is traded in substan...
# 2      <p>Insignificant numbers of <em>Melanochelys t...
# 3      <em>Morenia ocellata</em> is usually collected...
# 4      There is substantial collection of <em>Morenia...
# ...                                                  ...
# 19243                                                NaN
# 19244                                                NaN
# 19245                                                NaN
# 19246                 This species is not used in trade.
# 19247  <p>This species is commercially fished. It has...
#
#                                        systems  \
# 0      Terrestrial|Freshwater (=Inland waters)
# 1      Terrestrial|Freshwater (=Inland waters)
# 2      Terrestrial|Freshwater (=Inland waters)
# 3      Terrestrial|Freshwater (=Inland waters)
# 4      Terrestrial|Freshwater (=Inland waters)
# ...                                        ...
# 19243                              Terrestrial
# 19244                              Terrestrial
# 19245                              Terrestrial
# 19246                              Terrestrial
# 19247              Freshwater (=Inland waters)
#
#                                      conservationActions         realm  \
# 0      <p><em>Heosemys annandalii </em>is included in...   Indomalayan
# 1      <p><em>Lissemys scutata</em> is included in CI...   Indomalayan
# 2      <em>Melanochelys trijuga </em>was included in ...   Indomalayan
# 3      <p><em>Morenia ocellata</em> is listed in Appe...   Indomalayan
# 4      <p><em>Morenia petersi</em> was listed in CITE...   Indomalayan
# ...                                                  ...           ...
# 19243  <p><span lang="EN-US">There are no specific co...  Australasian
# 19244  <p><span lang="EN-US">There are no conservatio...  Australasian
# 19245  No breeding colonies are known from protected ...   Indomalayan
# 19246  <p><span lang="EN-US">No specific conservation...  Australasian
# 19247  Conservation actions are under way to re-estab...    Palearctic
#
#       yearLastSeen possiblyExtinct possiblyExtinctInTheWild  scopes  \
# 0              NaN           False                    False  Global
# 1              NaN           False                    False  Global
# 2              NaN           False                    False  Global
# 3              NaN           False                    False  Global
# 4              NaN           False                    False  Global
# ...            ...             ...                      ...     ...
# 19243          NaN           False                    False  Global
# 19244          NaN           False                    False  Global
# 19245          NaN           False                    False  Global
# 19246          NaN           False                    False  Global
# 19247          NaN           False                    False  Global
#
#                          habitats
# 0      ArtificialAquatic & Marine
# 1      ArtificialAquatic & Marine
# 2      ArtificialAquatic & Marine
# 3      ArtificialAquatic & Marine
# 4      ArtificialAquatic & Marine
# ...                           ...
# 19243           Wetlands (inland)
# 19244           Wetlands (inland)
# 19245           Wetlands (inland)
# 19246           Wetlands (inland)
# 19247           Wetlands (inland)
#
# [104393 rows x 24 columns]

# %%
# Out:
#        assessmentId  internalTaxonId        scientificName  \
# 0            495907            10041   Heosemys annandalii
# 1            505402            12124      Lissemys scutata
# 2            511745            13039  Melanochelys trijuga
# 3            544192            13873      Morenia ocellata
# 4            544248            13874       Morenia petersi
# ...             ...              ...                   ...
# 19243     209535016         71531227     Ozimops lumsdenae
# 19244     209550467         71533043         Ozimops ridei
# 19245     209553784            13564    Miniopterus fuscus
# 19246     209554228         71534469       Ozimops petersi
# 19247     210023750           166137     Carassius cuvieri
#
#              redlistCategory   redlistCriteria  yearPublished  \
# 0      Critically Endangered          A2cd+4cd           2021
# 1              Least Concern               NaN           2021
# 2              Least Concern               NaN           2020
# 3                 Endangered          A2cd+4cd           2021
# 4                 Endangered          A2cd+4cd           2021
# ...                      ...               ...            ...
# 19243          Least Concern               NaN           2021
# 19244          Least Concern               NaN           2017
# 19245             Endangered         B2ab(iii)           2021
# 19246          Least Concern               NaN           2021
# 19247             Endangered  A2c; B1ab(iii,v)           2019
#
#                 assessmentDate  criteriaVersion language  \
# 0      2018-03-13 00:00:00 UTC              3.1  English
# 1      2018-03-14 00:00:00 UTC              3.1  English
# 2      2018-03-12 00:00:00 UTC              3.1  English
# 3      2018-03-05 00:00:00 UTC              3.1  English
# 4      2018-03-13 00:00:00 UTC              3.1  English
# ...                        ...              ...      ...
# 19243  2016-07-31 00:00:00 UTC              3.1  English
# 19244  2016-07-29 00:00:00 UTC              3.1  English
# 19245  2018-07-25 00:00:00 UTC              3.1  English
# 19246  2018-08-31 00:00:00 UTC              3.1  English
# 19247  2017-12-08 00:00:00 UTC              3.1  English
#
#                                                rationale  ...  \
# 0      <p><em>Heosemys annandalii</em> is considered ...  ...
# 1      <em>Lissemys scutata</em> is listed as Least C...  ...
# 2      <p>A widespread, adaptable species with a subs...  ...
# 3      <p><em>Morenia ocellata</em> is listed as Enda...  ...
# 4      <p><em>Morenia petersi</em> appears to have su...  ...
# ...                                                  ...  ...
# 19243  <p><span class="datalabel1"><em>Ozimops lumsde...  ...
# 19244  <p><span lang="EN-AU">This species has a large...  ...
# 19245  This species is assessed as Endangered under c...  ...
# 19246  This species has a large extent of occurrence ...  ...
# 19247  This species has undergone at least a 50% popu...  ...
#
#                                                    range  \
# 0      <p>The range of <em>Heosemys annandalii</em> i...
# 1      <em>Lissemys scutata</em> is endemic to Myanma...
# 2      <p><em>Melanochelys trijuga</em> occurs across...
# 3      <p><em>Morenia ocellata</em> was generally con...
# 4      <p><em>Morenia petersi</em> occurs widely thro...
# ...                                                  ...
# 19243  <p><span lang="EN-US">This bat species occurs ...
# 19244  <p><span lang="EN-US">This species occurs alon...
# 19245  <p><span lang="EN-US">This species is endemic ...
# 19246  A widespread species found in arid to semi-ari...
# 19247  <span>This species is endemic to Lake Biwa and...
#
#                                                 useTrade  \
# 0      The species is collected for local consumption...
# 1      <em>Lissemys scutata</em> is traded in substan...
# 2      <p>Insignificant numbers of <em>Melanochelys t...
# 3      <em>Morenia ocellata</em> is usually collected...
# 4      There is substantial collection of <em>Morenia...
# ...                                                  ...
# 19243                                                NaN
# 19244                                                NaN
# 19245                                                NaN
# 19246                 This species is not used in trade.
# 19247  <p>This species is commercially fished. It has...
#
#                                        systems  \
# 0      Terrestrial|Freshwater (=Inland waters)
# 1      Terrestrial|Freshwater (=Inland waters)
# 2      Terrestrial|Freshwater (=Inland waters)
# 3      Terrestrial|Freshwater (=Inland waters)
# 4      Terrestrial|Freshwater (=Inland waters)
# ...                                        ...
# 19243                              Terrestrial
# 19244                              Terrestrial
# 19245                              Terrestrial
# 19246                              Terrestrial
# 19247              Freshwater (=Inland waters)
#
#                                      conservationActions         realm  \
# 0      <p><em>Heosemys annandalii </em>is included in...   Indomalayan
# 1      <p><em>Lissemys scutata</em> is included in CI...   Indomalayan
# 2      <em>Melanochelys trijuga </em>was included in ...   Indomalayan
# 3      <p><em>Morenia ocellata</em> is listed in Appe...   Indomalayan
# 4      <p><em>Morenia petersi</em> was listed in CITE...   Indomalayan
# ...                                                  ...           ...
# 19243  <p><span lang="EN-US">There are no specific co...  Australasian
# 19244  <p><span lang="EN-US">There are no conservatio...  Australasian
# 19245  No breeding colonies are known from protected ...   Indomalayan
# 19246  <p><span lang="EN-US">No specific conservation...  Australasian
# 19247  Conservation actions are under way to re-estab...    Palearctic
#
#       yearLastSeen possiblyExtinct possiblyExtinctInTheWild  scopes  \
# 0              NaN           False                    False  Global
# 1              NaN           False                    False  Global
# 2              NaN           False                    False  Global
# 3              NaN           False                    False  Global
# 4              NaN           False                    False  Global
# ...            ...             ...                      ...     ...
# 19243          NaN           False                    False  Global
# 19244          NaN           False                    False  Global
# 19245          NaN           False                    False  Global
# 19246          NaN           False                    False  Global
# 19247          NaN           False                    False  Global
#
#                          habitats
# 0      ArtificialAquatic & Marine
# 1      ArtificialAquatic & Marine
# 2      ArtificialAquatic & Marine
# 3      ArtificialAquatic & Marine
# 4      ArtificialAquatic & Marine
# ...                           ...
# 19243           Wetlands (inland)
# 19244           Wetlands (inland)
# 19245           Wetlands (inland)
# 19246           Wetlands (inland)
# 19247           Wetlands (inland)
#
# [104393 rows x 24 columns]

# %%
# Out:
#        assessmentId  internalTaxonId        scientificName  \
# 0            495907            10041   Heosemys annandalii
# 1            505402            12124      Lissemys scutata
# 2            511745            13039  Melanochelys trijuga
# 3            544192            13873      Morenia ocellata
# 4            544248            13874       Morenia petersi
# ...             ...              ...                   ...
# 19243     209535016         71531227     Ozimops lumsdenae
# 19244     209550467         71533043         Ozimops ridei
# 19245     209553784            13564    Miniopterus fuscus
# 19246     209554228         71534469       Ozimops petersi
# 19247     210023750           166137     Carassius cuvieri
#
#              redlistCategory   redlistCriteria  yearPublished  \
# 0      Critically Endangered          A2cd+4cd           2021
# 1              Least Concern               NaN           2021
# 2              Least Concern               NaN           2020
# 3                 Endangered          A2cd+4cd           2021
# 4                 Endangered          A2cd+4cd           2021
# ...                      ...               ...            ...
# 19243          Least Concern               NaN           2021
# 19244          Least Concern               NaN           2017
# 19245             Endangered         B2ab(iii)           2021
# 19246          Least Concern               NaN           2021
# 19247             Endangered  A2c; B1ab(iii,v)           2019
#
#                 assessmentDate  criteriaVersion language  \
# 0      2018-03-13 00:00:00 UTC              3.1  English
# 1      2018-03-14 00:00:00 UTC              3.1  English
# 2      2018-03-12 00:00:00 UTC              3.1  English
# 3      2018-03-05 00:00:00 UTC              3.1  English
# 4      2018-03-13 00:00:00 UTC              3.1  English
# ...                        ...              ...      ...
# 19243  2016-07-31 00:00:00 UTC              3.1  English
# 19244  2016-07-29 00:00:00 UTC              3.1  English
# 19245  2018-07-25 00:00:00 UTC              3.1  English
# 19246  2018-08-31 00:00:00 UTC              3.1  English
# 19247  2017-12-08 00:00:00 UTC              3.1  English
#
#                                                rationale  ...  \
# 0      <p><em>Heosemys annandalii</em> is considered ...  ...
# 1      <em>Lissemys scutata</em> is listed as Least C...  ...
# 2      <p>A widespread, adaptable species with a subs...  ...
# 3      <p><em>Morenia ocellata</em> is listed as Enda...  ...
# 4      <p><em>Morenia petersi</em> appears to have su...  ...
# ...                                                  ...  ...
# 19243  <p><span class="datalabel1"><em>Ozimops lumsde...  ...
# 19244  <p><span lang="EN-AU">This species has a large...  ...
# 19245  This species is assessed as Endangered under c...  ...
# 19246  This species has a large extent of occurrence ...  ...
# 19247  This species has undergone at least a 50% popu...  ...
#
#                                                    range  \
# 0      <p>The range of <em>Heosemys annandalii</em> i...
# 1      <em>Lissemys scutata</em> is endemic to Myanma...
# 2      <p><em>Melanochelys trijuga</em> occurs across...
# 3      <p><em>Morenia ocellata</em> was generally con...
# 4      <p><em>Morenia petersi</em> occurs widely thro...
# ...                                                  ...
# 19243  <p><span lang="EN-US">This bat species occurs ...
# 19244  <p><span lang="EN-US">This species occurs alon...
# 19245  <p><span lang="EN-US">This species is endemic ...
# 19246  A widespread species found in arid to semi-ari...
# 19247  <span>This species is endemic to Lake Biwa and...
#
#                                                 useTrade  \
# 0      The species is collected for local consumption...
# 1      <em>Lissemys scutata</em> is traded in substan...
# 2      <p>Insignificant numbers of <em>Melanochelys t...
# 3      <em>Morenia ocellata</em> is usually collected...
# 4      There is substantial collection of <em>Morenia...
# ...                                                  ...
# 19243                                                NaN
# 19244                                                NaN
# 19245                                                NaN
# 19246                 This species is not used in trade.
# 19247  <p>This species is commercially fished. It has...
#
#                                        systems  \
# 0      Terrestrial|Freshwater (=Inland waters)
# 1      Terrestrial|Freshwater (=Inland waters)
# 2      Terrestrial|Freshwater (=Inland waters)
# 3      Terrestrial|Freshwater (=Inland waters)
# 4      Terrestrial|Freshwater (=Inland waters)
# ...                                        ...
# 19243                              Terrestrial
# 19244                              Terrestrial
# 19245                              Terrestrial
# 19246                              Terrestrial
# 19247              Freshwater (=Inland waters)
#
#                                      conservationActions         realm  \
# 0      <p><em>Heosemys annandalii </em>is included in...   Indomalayan
# 1      <p><em>Lissemys scutata</em> is included in CI...   Indomalayan
# 2      <em>Melanochelys trijuga </em>was included in ...   Indomalayan
# 3      <p><em>Morenia ocellata</em> is listed in Appe...   Indomalayan
# 4      <p><em>Morenia petersi</em> was listed in CITE...   Indomalayan
# ...                                                  ...           ...
# 19243  <p><span lang="EN-US">There are no specific co...  Australasian
# 19244  <p><span lang="EN-US">There are no conservatio...  Australasian
# 19245  No breeding colonies are known from protected ...   Indomalayan
# 19246  <p><span lang="EN-US">No specific conservation...  Australasian
# 19247  Conservation actions are under way to re-estab...    Palearctic
#
#       yearLastSeen possiblyExtinct possiblyExtinctInTheWild  scopes  \
# 0              NaN           False                    False  Global
# 1              NaN           False                    False  Global
# 2              NaN           False                    False  Global
# 3              NaN           False                    False  Global
# 4              NaN           False                    False  Global
# ...            ...             ...                      ...     ...
# 19243          NaN           False                    False  Global
# 19244          NaN           False                    False  Global
# 19245          NaN           False                    False  Global
# 19246          NaN           False                    False  Global
# 19247          NaN           False                    False  Global
#
#                          habitats
# 0      ArtificialAquatic & Marine
# 1      ArtificialAquatic & Marine
# 2      ArtificialAquatic & Marine
# 3      ArtificialAquatic & Marine
# 4      ArtificialAquatic & Marine
# ...                           ...
# 19243           Wetlands (inland)
# 19244           Wetlands (inland)
# 19245           Wetlands (inland)
# 19246           Wetlands (inland)
# 19247           Wetlands (inland)
#
# [104393 rows x 24 columns]

# %%
habitats["habitats"] = habitats["habitats"].str[:-4]

# %%
habitats
# Out:
#        assessmentId  internalTaxonId        scientificName  \
# 0            495907            10041   Heosemys annandalii
# 1            505402            12124      Lissemys scutata
# 2            511745            13039  Melanochelys trijuga
# 3            544192            13873      Morenia ocellata
# 4            544248            13874       Morenia petersi
# ...             ...              ...                   ...
# 19243     209535016         71531227     Ozimops lumsdenae
# 19244     209550467         71533043         Ozimops ridei
# 19245     209553784            13564    Miniopterus fuscus
# 19246     209554228         71534469       Ozimops petersi
# 19247     210023750           166137     Carassius cuvieri
#
#              redlistCategory   redlistCriteria  yearPublished  \
# 0      Critically Endangered          A2cd+4cd           2021
# 1              Least Concern               NaN           2021
# 2              Least Concern               NaN           2020
# 3                 Endangered          A2cd+4cd           2021
# 4                 Endangered          A2cd+4cd           2021
# ...                      ...               ...            ...
# 19243          Least Concern               NaN           2021
# 19244          Least Concern               NaN           2017
# 19245             Endangered         B2ab(iii)           2021
# 19246          Least Concern               NaN           2021
# 19247             Endangered  A2c; B1ab(iii,v)           2019
#
#                 assessmentDate  criteriaVersion language  \
# 0      2018-03-13 00:00:00 UTC              3.1  English
# 1      2018-03-14 00:00:00 UTC              3.1  English
# 2      2018-03-12 00:00:00 UTC              3.1  English
# 3      2018-03-05 00:00:00 UTC              3.1  English
# 4      2018-03-13 00:00:00 UTC              3.1  English
# ...                        ...              ...      ...
# 19243  2016-07-31 00:00:00 UTC              3.1  English
# 19244  2016-07-29 00:00:00 UTC              3.1  English
# 19245  2018-07-25 00:00:00 UTC              3.1  English
# 19246  2018-08-31 00:00:00 UTC              3.1  English
# 19247  2017-12-08 00:00:00 UTC              3.1  English
#
#                                                rationale  ...  \
# 0      <p><em>Heosemys annandalii</em> is considered ...  ...
# 1      <em>Lissemys scutata</em> is listed as Least C...  ...
# 2      <p>A widespread, adaptable species with a subs...  ...
# 3      <p><em>Morenia ocellata</em> is listed as Enda...  ...
# 4      <p><em>Morenia petersi</em> appears to have su...  ...
# ...                                                  ...  ...
# 19243  <p><span class="datalabel1"><em>Ozimops lumsde...  ...
# 19244  <p><span lang="EN-AU">This species has a large...  ...
# 19245  This species is assessed as Endangered under c...  ...
# 19246  This species has a large extent of occurrence ...  ...
# 19247  This species has undergone at least a 50% popu...  ...
#
#                                                    range  \
# 0      <p>The range of <em>Heosemys annandalii</em> i...
# 1      <em>Lissemys scutata</em> is endemic to Myanma...
# 2      <p><em>Melanochelys trijuga</em> occurs across...
# 3      <p><em>Morenia ocellata</em> was generally con...
# 4      <p><em>Morenia petersi</em> occurs widely thro...
# ...                                                  ...
# 19243  <p><span lang="EN-US">This bat species occurs ...
# 19244  <p><span lang="EN-US">This species occurs alon...
# 19245  <p><span lang="EN-US">This species is endemic ...
# 19246  A widespread species found in arid to semi-ari...
# 19247  <span>This species is endemic to Lake Biwa and...
#
#                                                 useTrade  \
# 0      The species is collected for local consumption...
# 1      <em>Lissemys scutata</em> is traded in substan...
# 2      <p>Insignificant numbers of <em>Melanochelys t...
# 3      <em>Morenia ocellata</em> is usually collected...
# 4      There is substantial collection of <em>Morenia...
# ...                                                  ...
# 19243                                                NaN
# 19244                                                NaN
# 19245                                                NaN
# 19246                 This species is not used in trade.
# 19247  <p>This species is commercially fished. It has...
#
#                                        systems  \
# 0      Terrestrial|Freshwater (=Inland waters)
# 1      Terrestrial|Freshwater (=Inland waters)
# 2      Terrestrial|Freshwater (=Inland waters)
# 3      Terrestrial|Freshwater (=Inland waters)
# 4      Terrestrial|Freshwater (=Inland waters)
# ...                                        ...
# 19243                              Terrestrial
# 19244                              Terrestrial
# 19245                              Terrestrial
# 19246                              Terrestrial
# 19247              Freshwater (=Inland waters)
#
#                                      conservationActions         realm  \
# 0      <p><em>Heosemys annandalii </em>is included in...   Indomalayan
# 1      <p><em>Lissemys scutata</em> is included in CI...   Indomalayan
# 2      <em>Melanochelys trijuga </em>was included in ...   Indomalayan
# 3      <p><em>Morenia ocellata</em> is listed in Appe...   Indomalayan
# 4      <p><em>Morenia petersi</em> was listed in CITE...   Indomalayan
# ...                                                  ...           ...
# 19243  <p><span lang="EN-US">There are no specific co...  Australasian
# 19244  <p><span lang="EN-US">There are no conservatio...  Australasian
# 19245  No breeding colonies are known from protected ...   Indomalayan
# 19246  <p><span lang="EN-US">No specific conservation...  Australasian
# 19247  Conservation actions are under way to re-estab...    Palearctic
#
#       yearLastSeen possiblyExtinct possiblyExtinctInTheWild  scopes  \
# 0              NaN           False                    False  Global
# 1              NaN           False                    False  Global
# 2              NaN           False                    False  Global
# 3              NaN           False                    False  Global
# 4              NaN           False                    False  Global
# ...            ...             ...                      ...     ...
# 19243          NaN           False                    False  Global
# 19244          NaN           False                    False  Global
# 19245          NaN           False                    False  Global
# 19246          NaN           False                    False  Global
# 19247          NaN           False                    False  Global
#
#                          habitats
# 0      ArtificialAquatic & Marine
# 1      ArtificialAquatic & Marine
# 2      ArtificialAquatic & Marine
# 3      ArtificialAquatic & Marine
# 4      ArtificialAquatic & Marine
# ...                           ...
# 19243           Wetlands (inland)
# 19244           Wetlands (inland)
# 19245           Wetlands (inland)
# 19246           Wetlands (inland)
# 19247           Wetlands (inland)
#
# [104393 rows x 24 columns]

# %%
df.rename(lambda x: x.str[:-4] if '_x' in x else x, axis=1)
# Out:
# array([False,  True])

# %%
#Data Acquisition
def import_files_from_directory_with_file_name_column_into_list(directory_path,column_name):
    files_list = [f for f in listdir(directory_path) if isfile(join(directory_path, f))]
    df_list = []
    for i in files_list:
        df = pd.read_csv(directory_path + i)
        df[column_name] = i
        df[column_name] = df[column_name].str[:-4]
        df_list.append(df)
    return df_list

path_threats = '../data/threats/'
column_name_threats = "threat"

df_threats = import_files_from_directory_with_file_name_column_into_list(path_threats,column_name_threats)
threats = pd.concat(df_threats)
threats
# Out:
#      assessmentId  internalTaxonId          scientificName  \
# 0        498476.0          10769.0     Ictalurus mexicanus
# 1        498826.0      132521900.0          Ilyodon whitei
# 2        499158.0          10825.0   Indotestudo forstenii
# 3        505402.0          12124.0        Lissemys scutata
# 4        508210.0          12696.0  Malacochersus tornieri
# ..            ...              ...                     ...
# 202   206316110.0       22696362.0       Falco tinnunculus
# 203   206456835.0       22696092.0     Hieraaetus pennatus
# 204   206523296.0      155019854.0              Otus scops
# 205   206588554.0      181568721.0          Milvus migrans
# 206   206634667.0       61695117.0             Buteo buteo
#
#            redlistCategory redlistCriteria  yearPublished  \
# 0               Vulnerable              D2         2019.0
# 1            Least Concern             NaN         2019.0
# 2    Critically Endangered            A4cd         2021.0
# 3            Least Concern             NaN         2021.0
# 4    Critically Endangered          A4abcd         2019.0
# ..                     ...             ...            ...
# 202          Least Concern             NaN         2021.0
# 203          Least Concern             NaN         2021.0
# 204          Least Concern             NaN         2021.0
# 205          Least Concern             NaN         2021.0
# 206          Least Concern             NaN         2021.0
#
#               assessmentDate  criteriaVersion language  \
# 0    2018-12-06 00:00:00 UTC              3.1  English
# 1    2018-04-18 00:00:00 UTC              3.1  English
# 2    2018-03-14 00:00:00 UTC              3.1  English
# 3    2018-03-14 00:00:00 UTC              3.1  English
# 4    2018-10-25 00:00:00 UTC              3.1  English
# ..                       ...              ...      ...
# 202  2021-08-10 00:00:00 UTC              3.1  English
# 203  2021-08-12 00:00:00 UTC              3.1  English
# 204  2021-08-13 00:00:00 UTC              3.1  English
# 205  2021-08-16 00:00:00 UTC              3.1  English
# 206  2021-08-18 00:00:00 UTC              3.1  English
#
#                                              rationale  ...  \
# 0    <em>I. mexicanus </em>is herein categorized as...  ...
# 1    The Balsas Splitfin inhabits the Upper Río Coa...  ...
# 2    This assessment refers to the Sulawesi populat...  ...
# 3    <em>Lissemys scutata</em> is listed as Least C...  ...
# 4    <em>Malacochersus tornieri</em>&#160;is severe...  ...
# ..                                                 ...  ...
# 202  This species has an extremely large range, and...  ...
# 203  This species has an extremely large range, and...  ...
# 204  This species has an extremely large range, and...  ...
# 205  This species has an extremely large range, and...  ...
# 206  This species has an extremely large range, and...  ...
#
#                                                 threat Unnamed: 0 total_id  \
# 0    Agriculture & aquaculture-Annual & perennial n...        NaN      NaN
# 1    Agriculture & aquaculture-Annual & perennial n...        NaN      NaN
# 2    Agriculture & aquaculture-Annual & perennial n...        NaN      NaN
# 3    Agriculture & aquaculture-Annual & perennial n...        NaN      NaN
# 4    Agriculture & aquaculture-Annual & perennial n...        NaN      NaN
# ..                                                 ...        ...      ...
# 202  Transportation & service corridors-Utility & s...        NaN      NaN
# 203  Transportation & service corridors-Utility & s...        NaN      NaN
# 204  Transportation & service corridors-Utility & s...        NaN      NaN
# 205  Transportation & service corridors-Utility & s...        NaN      NaN
# 206  Transportation & service corridors-Utility & s...        NaN      NaN
#
#     kingdomName phylumName className orderName familyName sub-threat  url
# 0           NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 1           NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 2           NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 3           NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 4           NaN        NaN       NaN       NaN        NaN        NaN  NaN
# ..          ...        ...       ...       ...        ...        ...  ...
# 202         NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 203         NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 204         NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 205         NaN        NaN       NaN       NaN        NaN        NaN  NaN
# 206         NaN        NaN       NaN       NaN        NaN        NaN  NaN
#
# [89735 rows x 33 columns]

# %%
threats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89735 entries, 0 to 206
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   assessmentId              89735 non-null  float64
#  1   internalTaxonId           89735 non-null  float64
#  2   scientificName            89735 non-null  object
#  3   redlistCategory           89735 non-null  object
#  4   redlistCriteria           45554 non-null  object
#  5   yearPublished             89735 non-null  float64
#  6   assessmentDate            89735 non-null  object
#  7   criteriaVersion           89735 non-null  float64
#  8   language                  89735 non-null  object
#  9   rationale                 89728 non-null  object
#  10  habitat                   89200 non-null  object
#  11  threats                   89405 non-null  object
#  12  population                89529 non-null  object
#  13  populationTrend           88888 non-null  object
#  14  range                     88706 non-null  object
#  15  useTrade                  61317 non-null  object
#  16  systems                   89735 non-null  object
#  17  conservationActions       88549 non-null  object
#  18  realm                     84374 non-null  object
#  19  yearLastSeen              2310 non-null   object
#  20  possiblyExtinct           89735 non-null  object
#  21  possiblyExtinctInTheWild  89735 non-null  object
#  22  scopes                    89735 non-null  object
#  23  threat                    89735 non-null  object
#  24  Unnamed: 0                0 non-null      object
#  25  total_id                  0 non-null      object
#  26  kingdomName               0 non-null      object
#  27  phylumName                0 non-null      object
#  28  className                 0 non-null      object
#  29  orderName                 0 non-null      object
#  30  familyName                0 non-null      object
#  31  sub-threat                0 non-null      object
#  32  url                       0 non-null      object
# dtypes: float64(4), object(29)
# memory usage: 23.3+ MB
